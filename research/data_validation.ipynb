# %%
import pandas as pd
import os

# %%
# %pwd
# Out:
# '/Users/ntchindagiscard/Documents/end-end-mlflow/research'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# '/Users/ntchindagiscard/Documents/end-end-mlflow'

# %%
from dataclasses import dataclass
from pathlib import Path
from typing import List

@dataclass(frozen=True)
class DataValidationConfig:
    root_dir: str
    unzip_file_dir: dict
    STATUS_FILE: str
    all_schema: dict

# %%
from mlProject.constants import *
from mlProject.utils.common import read_yaml, create_directories

# %%
from mlProject.utils.common import (
    # create_directories,
      read_yaml)
from mlProject import logger



class ConfigurationManager:
    def __init__(
            self,
            config_filepath = CONFIG_FILE_PATH,
            params_filepath = PARAMS_FILE_PATH,
            schema_filepath = SCHEMA_FILE_PATH
            ) -> None:
        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        self.schema = read_yaml(schema_filepath)

        create_directories([self.config.artifacts_root])

    def get_data_validation_configuration(self) -> DataValidationConfig:

        config  = self.config.data_validations
        schema = self.schema


        create_directories([config.root_dir])

        data_validation_config = DataValidationConfig(
            all_schema= schema,
            unzip_file_dir = {'movies': config.movies, 'tags': config.tags, 'ratings': config.ratings},
            root_dir= config.root_dir,
            STATUS_FILE= config.STATUS_FILE
        )


        return data_validation_config

# %%
import os
from mlProject import logger

# %%
class DataValidation:

    def __init__(self, config: DataValidationConfig) -> None:
        
        self.config = config
    
    def validate_all_columns(self) -> bool:

        try:
            validation_status = None
            data = pd.read_csv(self.config.unzip_file_dir)
            all_cols = list(data.columns)
            all_schema = self.config.all_schema.keys()

            for col in all_cols:
                if col not in all_schema:
                    validation_status = False

                    with open(self.config.STATUS_FILE, 'w') as f:
                        f.write(f"validation status: {validation_status}")
                
                else:
                    validation_status = True
                    with open(self.config.STATUS_FILE, 'w') as f:
                        f.write(f"validation status: {validation_status}")
            
            return validation_status

        except Exception as e:
            raise e

# %%
# import pandera as pa
# import pandas as pd
# from pandera import Column, DataFrameSchema
# from mlProject.base import DataValidator
# from typing import Dict
# import yaml
# import logging

# logger = logging.getLogger(__name__)

# # Mapping from string type to Pandera type
# TYPE_MAPPING = {
#     'int': pa.Int,
#     'float': pa.Float,
#     'str': pa.String
# }

# class SchemaValidator(DataValidator):

#     def __init__(self, schema_config: Dict[str, Dict[str, Dict[str, str]]]) -> None:
#         self.schema_config = schema_config

#     def get_schema(self, dataset_name: str) -> DataFrameSchema:
#         columns = self.schema_config[dataset_name]['columns']
#         schema_dict = {col: Column(TYPE_MAPPING[col_type]) for col, col_type in columns.items()}
#         return DataFrameSchema(schema_dict, strict=True)

#     def validate(self, dataset_name: str, df: pd.DataFrame) -> bool:
#         schema = self.get_schema(dataset_name)
#         try:
#             schema.validate(df)
#             logger.info(f"{dataset_name} validation passed")
#             return True
#         except pa.errors.SchemaError as e:
#             logger.exception(f"{dataset_name} schema validation error: {e}")
#             return False

# # Load schema from YAML file
# with open('schema.yaml', 'r') as file:
#     schema_config = yaml.safe_load(file)

# # Example usage
# validator = SchemaValidator(schema_config=schema_config)
# df_movies = pd.read_csv('path_to_movies.csv')
# validator.validate('movies', df_movies)

# %%
import pandera as pa
import pandas as pd
from pandera import Column, DataFrameSchema
from mlProject.base import DataValidator
from typing import List, Dict

# Mapping from string type to Pandera type
TYPE_MAPPING = {
    'int': pa.Int,
    'float': pa.Float,
    'str': pa.String
}

class SchemaValidator(DataValidator):

    def __init__(self, columns: Dict,  dataset_name: str) -> None:
        self.columns = columns
        self. dataset_name =  dataset_name

    def get_schema(self) -> bool:      
        schema_dict = {col: Column(TYPE_MAPPING[col_type]) for col, col_type in self.columns.items()}
        return DataFrameSchema(schema_dict, strict=True)

    def validate(self, df: pd.DataFrame) -> bool:
        schema = self.get_schema()
        try:
            schema.validate(df)
            logger.info(f"Schema validation for {self.dataset_name}  passed")
            return True
        except pa.errors.SchemaError as e:
            logger.exception(f"Schema validation for {self.dataset_name}   failed: {e}")
            return False

# %%
from evidently.test_suite import TestSuite
from evidently.tests import TestColumnQuantile
from evidently.tests.data_quality_tests import TestValueRange

from mlProject.base import DataValidator
import pandas as pd

class DataRangeValidator(DataValidator):
    def __init__(self, min_value: float, max_value: float):
        self.column_name = 'rating'
        self.min_value = min_value
        self.max_value = max_value


    def validate(self, df: pd.DataFrame) -> bool:
        test_suite = TestSuite(tests=[
            TestValueRange(
                column_name = self.column_name,
                left = self.min_value,
                right =self.max_value
            )
        ])
        test_suite.run(reference_data=df, current_data=df)
        results = test_suite.as_dict()
        test_statuses = [test['status'] for test in results['tests']]
        logger.info(f"Statuses of ran tests: {results} ")
        if all(status == 'SUCCESS' for status in test_statuses):
            logger.info(f"Data range validation for '{self.column_name}' passed.")
            return True
        else:
            logger.info(f"Data range validation for '{self.column_name}' failed.")
            return False

# %%
import pandas as pd

class CSVDataValidator:
    def __init__(self, config: DataValidationConfig):
        
        self.schema = config.all_schema
        self.config = config
        

    def load_dataset(self, file_path: str) -> pd.DataFrame:
        return pd.read_csv(file_path)

    def validate_dataset(self):

        try:
            for dataset_name in self.schema:
                df = self.load_dataset(self.config.unzip_file_dir[dataset_name])
                schema_validator = SchemaValidator(columns=self.schema[dataset_name].columns, dataset_name=dataset_name)
                if schema_validator.validate(df):
                    if dataset_name == 'ratings': 
                        range_validator = DataRangeValidator(self.schema[dataset_name].rating_range.min_value, self.schema[dataset_name].rating_range.max_value)
                        range_validator.validate(df)
            return True
        except Exception as e:
            logger.exception(e)
            raise e

# %%
try:
    config = ConfigurationManager()
    data_validation_config = config.get_data_validation_configuration()
    data_validator = CSVDataValidator(config=data_validation_config)
    data_validator.validate_dataset()
except Exception as e:
    logger.exception(e)
    raise e
# Out:
# [2025-01-14 22:22:26,455: INFO: common: Yaml file : config/config.yaml loaded successfully]
# [2025-01-14 22:22:26,468: INFO: common: Yaml file : params.yaml loaded successfully]
# [2025-01-14 22:22:26,493: INFO: common: Yaml file : schema.yaml loaded successfully]
# [2025-01-14 22:22:26,500: INFO: common: Created directory at: artifacts]
# [2025-01-14 22:22:26,506: INFO: common: Created directory at: artifacts/data_validation]
# [2025-01-14 22:22:26,887: INFO: 2929335959: Schema validation for movies  passed]
# [2025-01-14 22:22:27,122: INFO: 2929335959: Schema validation for ratings  passed]
# [2025-01-14 22:22:27,578: INFO: 855803853: Statuses of ran tests: {'tests': [{'name': 'Value Range', 'description': 'All values in the column **rating** are within range', 'status': 'SUCCESS', 'group': 'data_quality', 'parameters': None}], 'summary': {'all_passed': True, 'total_tests': 1, 'success_tests': 1, 'failed_tests': 0, 'by_status': {'SUCCESS': 1}}} ]
# [2025-01-14 22:22:27,584: INFO: 855803853: Data range validation for 'rating' passed.]
# [2025-01-14 22:22:27,659: INFO: 2929335959: Schema validation for tags  passed]

# %%
try:
    config = ConfigurationManager()
    data_validation_config = config.get_data_validation_configuration()
    data_validator = DataValiadatorWithEvidently(config=data_validation_config)
    data_validator.validate('movies')
except Exception as e:
    raise e
# Out:
# [2025-01-11 09:49:34,387: INFO: common: Yaml file : config/config.yaml loaded successfully]
# [2025-01-11 09:49:34,403: INFO: common: Yaml file : params.yaml loaded successfully]
# [2025-01-11 09:49:34,433: INFO: common: Yaml file : schema.yaml loaded successfully]
# [2025-01-11 09:49:34,447: INFO: 2712473069: Created directory at: artifacts]
# [2025-01-11 09:49:34,456: INFO: 2712473069: Created directory at: artifacts/data_validation]
#  Columns of dataset ['movieId', 'title', 'genre']

# %%
# try:
#     config = ConfigurationManager()
#     data_validation_config = config.get_data_validation_configuration()
#     data_validation = DataValidation(config=data_validation_config)
#     data_validation.validate_all_columns()
# except Exception as e:
#     raise e
# Out:
# [2024-08-15 18:19:45,408: INFO: common: Yaml file : config/config.yaml loaded successfully]
# [2024-08-15 18:19:45,425: INFO: common: Yaml file : params.yaml loaded successfully]
# [2024-08-15 18:19:45,459: INFO: common: Yaml file : schema.yaml loaded successfully]
# [2024-08-15 18:19:45,468: INFO: 1077476401: Created directory at: artifacts]
# [2024-08-15 18:19:45,476: INFO: 1077476401: Created directory at: artifacts/data_validation]
